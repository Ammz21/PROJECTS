# %%
from sys import maxsize
from itertools import permutations
V=10
def travellingSalesmanProblem(graph, s):
    vertex = []
    for i in range(V):
        if i != s:
            vertex.append(i)
    min_path = maxsize
    next_permutation=permutations(vertex)
    for i in next_permutation:
        current_pathweight = 0
        k = s
        for j in i:
            current_pathweight += graph[k][j]
            k = j
        current_pathweight += graph[k][s]
        min_path = min(min_path, current_pathweight)
    return min_path
def main():
    n=int(input("Enter no of city"))
    city_dist=[]
    graph=[]
    for i in range(n):
        print('Node',i+1)
        for j in range(n):
            c_d=int(input('Enter distance from node'))
            city_dist.append(c_d)
        
        graph.append(city_dist)

    s = 0
    print(travellingSalesmanProblem(graph, s))
   
main()
# Out:
# Enter no of city10
# Node 1
# Enter distance from node8
# Enter distance from node6
# Enter distance from node5
# Enter distance from node5
# Enter distance from node9
# Enter distance from node8
# Enter distance from node7
# Enter distance from node4
# Enter distance from node6
# Enter distance from node9
# Node 2
# Enter distance from node3
# Enter distance from node2
# Enter distance from node1
# Enter distance from node4
# Enter distance from node7
# Enter distance from node8
# Enter distance from node9
# Enter distance from node5
# Enter distance from node6
# Enter distance from node9
# Node 3
# Enter distance from node8
# Enter distance from node47
# Enter distance from node4
# Enter distance from node5
# Enter distance from node11
# Enter distance from node25
# Enter distance from node10
# Enter distance from node65
# Enter distance from node8
# Enter distance from node9
# Node 4
# Enter distance from node4
# Enter distance from node6
# Enter distance from node7
# Enter distance from node1
# Enter distance from node2
# Enter distance from node3
# Enter distance from node9
# Enter distance from node8
# Enter distance from node7
# Enter distance from node4
# Node 5
# Enter distance from node5
# Enter distance from node6
# Enter distance from node9
# Enter distance from node8
# Enter distance from node5
# Enter distance from node2
# Enter distance from node6
# Enter distance from node5
# Enter distance from node8
# Enter distance from node4
# Node 6
# Enter distance from node2
# Enter distance from node7
# Enter distance from node8
# Enter distance from node9
# Enter distance from node6
# Enter distance from node5
# Enter distance from node8
# Enter distance from node4
# Enter distance from node2
# Enter distance from node5
# Node 7
# Enter distance from node8
# Enter distance from node9
# Enter distance from node6
# Enter distance from node7
# Enter distance from node5
# Enter distance from node8
# Enter distance from node9
# Enter distance from node6
# Enter distance from node5
# Enter distance from node8
# Node 8
# Enter distance from node4
# Enter distance from node11
# Enter distance from node12
# Enter distance from node14
# Enter distance from node15
# Enter distance from node8
# Enter distance from node9
# Enter distance from node7
# Enter distance from node9
# Enter distance from node1
# Node 9
# Enter distance from node6
# Enter distance from node16
# Enter distance from node8
# Enter distance from node7
# Enter distance from node9
# Enter distance from node5
# Enter distance from node3
# Enter distance from node5
# Enter distance from node4
# Enter distance from node9
# Node 10
# Enter distance from node8
# Enter distance from node7
# Enter distance from node16
# Enter distance from node14
# Enter distance from node12
# Enter distance from node8
# Enter distance from node7
# Enter distance from node9
# Enter distance from node11
# Enter distance from node8
# 67

# %% [markdown]
# ![tsm.png](attachment:tsm.png)
